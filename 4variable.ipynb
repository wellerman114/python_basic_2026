# %% [markdown]
# # 변수 : 자료형의 값을 저장하는 공간

# %%
a=1
b="python"
c=[1,2,3]
print(a,b,c)
# Out:
# 1 python [1, 2, 3]

# %% [markdown]
# ## 1. 변수란? 자료형의 데이텁 (값)
# - 데이터(객체)가 메모리에 생성
# - id() = 변수가 가리키고 있는 객체의 주소값을 리턴하는 파이썬의 내장함수

# %%
a=[1,2,3]
id(a)
# Out:
# 2088134825728

# %% [markdown]
# ##.2 리스트를 복사하고자 할때

# %%
a = [1,2,3]
b = a
b
# Out:
# [1, 2, 3]

# %%
a = "dog"
b = "animal"
c = "cat"
a = b
c = b
c==a
# Out:
# True

# %%
a = [1,2,3]
b = a
b
# Out:
# [1, 2, 3]

# %%
id(a)
# Out:
# 2088134937600

# %%
id(b)
# Out:
# 2088134937600

# %%
a is b #동일한 데이터(객체)를 가리키고 있는지 판단
# Out:
# True

# %%
a[1] =4
a
# Out:
# [1, 4, 3]

# %%
b
# Out:
# [1, 4, 3]

# %% [markdown]
# ###### b변수를 생성할 때 a 변수의 값을 가져오면서 a와는 다른 주소를 가리키도록 만드는법

# %%
# 방법 1 : [:] 이용하기
a = [1,2,3]
b = a[:]
a[1]=4
a
# Out:
# [1, 4, 3]

# %%
b
# Out:
# [1, 2, 3]

# %%
id(a)
# Out:
# 2088134451200

# %%
id(b)
# Out:
# 2088134982976

# %%
# 방법 2 : copy 모듈 이용하기 (from copy import copy)
from copy import copy
a=[1,2,3]
b=copy(a)

# %%
b
# Out:
# [1, 2, 3]

# %%
a
# Out:
# [1, 2, 3]

# %%
b is a
# Out:
# False

# %%
print(id(a),id(b))
# Out:
# 2088134977280 2088134968896

# %%
# 방법 3 : copy함수 사용하기
b = copy(a)

# %%
b is a
# Out:
# False

# %% [markdown]
# ## 3. 변수를 만드는 여러가지 방법

# %%
# 튜플로 변수 만들기
a,b=('python','life')
a
# Out:
# 'python'

# %%
b
# Out:
# 'life'

# %%
(a,b)='python','life'
a
# Out:
# 'python'

# %%
b
# Out:
# 'life'

# %%
# 리스트로 변수 만들기
[a,b]=['python','life']
a
# Out:
# 'python'

# %%
a,b
# Out:
# ('python', 'life')

# %%
# 여러개의 변수에 같은 값대입
a=b='python'
a
# Out:
# 'python'

# %%
b
# Out:
# 'python'

# %%
# 두 변수의 값 바꾸기 (일반적인 프로그래밍에서 두 변수 값 교체할 때)
a=3
b=5
a,b=b,a
a
# Out:
# 5

# %%
b
# Out:
# 3

# %%
temp = a
a = b
b =temp
print(a,b)
# Out:
# 5 3

# %%
# python 에서 
a=3
b=5
a,b=b,a
a,b
# Out:
# (5, 3)
