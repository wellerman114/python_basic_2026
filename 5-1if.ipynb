# %% [markdown]
# # 제어문 / 조건문 (if)

# %%
# ‘돈이 있으면 택시를 타고 가고, 돈이 없으면 걸어간다.’
money = True
if money:  
    print("택시타라")
else:
    print("걸어가라")
# Out:
# 택시타라

# %% [markdown]
# ## 1. if 문의 기본 구조

# %% [markdown]
# if 문은 무조건 들여쓰기를 해야한다.

# %% [markdown]
# if 조건문:​
#
#     수행할_문장1
#
#     수행할_문장2
#
#     ...
#
# else:
#
#     수행할_문장A
#
#     수행할_문장B
#
#     ...
#
# - ‘조건문’이란 참과 거짓을 판단하는 문장을 말한다.
#
# 조건문을 테스트해서 참이면 if 문 바로 다음 문장(if 블록)들을 수행하고 조건문이 거짓이면 else 문 다음 문장(else 블록)들을 수행하게 된다. 따라서 else 문은 if 문 없이 독립적으로 사용할 수 없다.

# %% [markdown]
# ## 2. 연산자

# %% [markdown]
# 비교 연산자 : < ,> ,  , == , != , >= , <=

# %%
x=3
y=2
x==y
# Out:
# False

# %%
x>y
# Out:
# True

# %%
x!=y
# Out:
# True

# %%
money = 2000
if money >= 3000:
    print("택시를 타라")
else:
    print("걸어가라")
# Out:
# 걸어가라

# %% [markdown]
# 논리 연산자 : and , or , not

# %% [markdown]
# x or y : 둘중 하나만 참이여도 참
# x and y : 모두 참이어야 참
# x not y : x가 거짓이면 참

# %%
money = 2000
card = True
if money >=3000 or card:
    print("택시타라")
else:
    print("걸어가라")
# Out:
# 택시타라

# %% [markdown]
# in,not in : 리스트[], 튜플() , 문자열"
# - 영어 단어 in의 뜻이 ‘~안에’라는 것을 생각해 보면 다음 예가 쉽게 이해될 것이다.

# %%
1 in [1,2,3]
# Out:
# True

# %%
1 not in [1,2,3]
# Out:
# False

# %%
'a' in ('a','b','c')
# Out:
# True

# %%
'j' not in 'python'
# Out:
# True

# %%
pocket=['money','cellphone','paper']
if 'money' in pocket:
    print('택시타라')
else:
    print('걸어가')
# Out:
# 택시타라

# %% [markdown]
# 아무일도 하지 않게 설정하는 법

# %%
if 'money' in pocket:
    pass
else:
    print("카드꺼내")

# %% [markdown]
# ## 3. 다양한 조건을 판단하는 elif
# - if와 else만으로는 다양한 조건을 판단하기 어려움.

# %%
# 주머니에 돈이 있으면 택시를 타고가고 주머니에 돈은 없지만 카드가 있으면 택시를 타고 둘다없으면 걸어가라

pocket = ['paper','cellphone']
card = True
if 'money' in pocket:
    print('택시타라')
elif card:
    print('텍시타라')
else:
    print('걸어가')
# Out:
# 텍시타라

# %% [markdown]
# ## 4. 조건부 표현식

# %% [markdown]
# 예재 : score가 60점 이상일때 success ,미만일때 failure 를 대입하는 코드

# %%
score = 55
if score >= 60:
    message='success'
else:
    message='failure'

print(message)
# Out:
# failure

# %%
pocket = ['paper','cellphone']
card = True
if 'money' in pocket:
    print('take a taxi')
elif card:
    print('take a taxi')
else:
    print('walk')
# Out:
# take a taxi
